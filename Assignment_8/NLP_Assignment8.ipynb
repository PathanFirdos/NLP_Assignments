# %%
# !pip install -q nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize

# %% [markdown]
# Example Ambiguous Sentences

# %%
sentences = [
    "He deposited money in the bank",
    "The fisherman sat on the bank of the river",
    "She went to the court to watch the match",
    "The judge works in the court"
]

# %% [markdown]
# # Apply WordNet-based WSD (Lesk Algorithm)

# %%
def apply_wsd(sentence, target_word):
    tokens = word_tokenize(sentence)
    sense = lesk(tokens, target_word)
    return sense

# %% [markdown]
# Perform Word Sense Disambiguation

# %%
for sentence in sentences:
    word = "bank" if "bank" in sentence else "court"
    sense = apply_wsd(sentence, word)

    print("Sentence:", sentence)
    if sense:
        print("Disambiguated Sense:", sense.name())
        print("Meaning:", sense.definition())
    else:
        print("No sense found")
    print("-" * 60)
# Out:
# Sentence: He deposited money in the bank
# Disambiguated Sense: savings_bank.n.02
# Meaning: a container (usually with a slot in the top) for keeping money at home
# ------------------------------------------------------------
# Sentence: The fisherman sat on the bank of the river
# Disambiguated Sense: bank.v.07
# Meaning: cover with ashes so to control the rate of burning
# ------------------------------------------------------------
# Sentence: She went to the court to watch the match
# Disambiguated Sense: court.n.08
# Meaning: a tribunal that is presided over by a magistrate or by one or more judges who administer justice according to the laws
# ------------------------------------------------------------
# Sentence: The judge works in the court
# Disambiguated Sense: court.v.03
# Meaning: engage in social activities leading to marriage
# ------------------------------------------------------------
